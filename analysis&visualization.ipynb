# %% [markdown]
# ### import packages

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.sandbox.regression.predstd import wls_prediction_std
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
sns.set_style('darkgrid')
pd.plotting.register_matplotlib_converters()
# %matplotlib inline

# %% [markdown]
# ### Building OLS Model
# 1. read in the processed file and build an ols model using test_rate, positive cases, and final_score
# 2. plot each regression line with residuals

# %%
df = pd.read_csv('output.csv', index_col=0)
model = smf.ols('death ~ test_rate + positive + final_score', data = df)
res = model.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  death   R-squared:                       0.944
# Model:                            OLS   Adj. R-squared:                  0.940
# Method:                 Least Squares   F-statistic:                     268.0
# Date:                Tue, 20 Apr 2021   Prob (F-statistic):           5.69e-30
# Time:                        19:17:05   Log-Likelihood:                -485.26
# No. Observations:                  52   AIC:                             978.5
# Df Residuals:                      48   BIC:                             986.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    2524.8615   1773.882      1.423      0.161   -1041.768    6091.491
# test_rate    2384.9830    848.127      2.812      0.007     679.709    4090.257
# positive        0.0170      0.001     27.873      0.000       0.016       0.018
# final_score   -25.2307     10.110     -2.496      0.016     -45.559      -4.903
# ==============================================================================
# Omnibus:                       18.436   Durbin-Watson:                   1.684
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.601
# Skew:                           1.196   Prob(JB):                     1.67e-06
# Kurtosis:                       5.560   Cond. No.                     3.84e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.84e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
plt.figure(figsize=(16,5))

#subplot(nrows, ncols, index)
plt.subplot(1, 3, 1)
sns.regplot(x="test_rate", y="death", data=df)

plt.subplot(1, 3, 2)
sns.regplot(x="positive", y="death", data=df) 

plt.subplot(1, 3, 3)
sns.regplot(x="final_score", y="death", data=df)
plt.show()

# %% [markdown]
# ### find the difference in scores between Red and Blue state (distinguished by each state's vote for the presidential election in 2020)
#
# 1. add a new column that describes which candidate did the state voted for
# 2. calculate the mean score for red and blue states using a groupby and agg function
# 3. plot individual state's score

# %%
state= {
    'Alabama': 'Trump',
    'Alaska': 'Trump',
    'American Samoa':'Biden',
    'Arizona':'Biden',
    'Arkansas':'Trump',
    'California':'Biden',
    'Colorado':'Biden',
    'Connecticut':'Biden',
    'Delaware':'Biden',
    'District of Columbia':'Biden',
    'Florida':'Trump',
    'Georgia':'Biden',
    'Guam':'Biden',
    'Hawaii':'Biden',
    'Idaho':'Trump',
    'Illinois':'Biden',
    'Indiana':'Trump',
    'Iowa':'Trump',
    'Kansas':'Trump',
    'Kentucky':'Trump',
    'Louisiana':'Trump',
    'Maine':'Biden',
    'Maryland':'Biden',
    'Massachusetts':'Biden',
    'Michigan':'Biden',
    'Minnesota':'Biden',
    'Mississippi':'Trump',
    'Missouri':'Trump',
    'Montana':'Trump',
    'Nebraska':'Trump',
    'Nevada':'Biden',
    'New Hampshire':'Biden',
    'New Jersey':'Biden',
    'New Mexico':'Biden',
    'New York':'Biden',
    'North Carolina':'Biden',
    'North Dakota':'Trump',
    'Northern Mariana Islands':'Biden',
    'Ohio':'Trump',
    'Oklahoma':'Trump',
    'Oregon':'Biden',
    'Pennsylvania':'Biden',
    'Puerto Rico':'Biden',
    'Rhode Island':'Biden',
    'South Carolina':'Trump',
    'South Dakota':'Trump',
    'Tennessee':'Trump',
    'Texas':'Trump',
    'Utah':'Trump',
    'Vermont':'Biden',
    'Virgin Islands':'Biden',
    'Virginia':'Biden',
    'Washington':'Biden',
    'West Virginia':'Trump',
    'Wisconsin':'Biden',
    'Wyoming':'Trump'
    }
politics = pd.Series(state, index = state.keys(), name='vote')
x = pd.merge(df, politics, left_on='state', right_on=politics.index)
x.groupby('vote').agg({'final_score':np.mean})
# Out:
#        final_score
# vote
# Biden   204.464286
# Trump   167.708333

# %%
agg_df = x.groupby(['vote','state']).agg({'final_score':np.mean}).reset_index()
agg_df['state']=agg_df['state'].astype('category')
agg_df = agg_df.sort_values(by=['final_score'])
g = sns.catplot(x="final_score", y="state",hue="vote",data=agg_df, kind="bar",\
    order = agg_df.sort_values(by=['final_score'],ascending=False).state, height=7, aspect=1.2, palette="Greys")
